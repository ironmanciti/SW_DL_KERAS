# %% [markdown]
# # 실습 : fashion MNIST 를 이용하여 위와 동일한 작업
#
# - Fashion MNIST 는 10 개 카테고리에 70,000 개의 회색조 이미지가 포함 된 [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) 데이터 세트.
#
# - 이미지는 다음과 같이 저해상도 (28 x 28 픽셀)의 개별 의류 품목을 보여준다.
#
# - 여기서 60,000 개의 이미지를 사용하여 네트워크를 훈련시키고 10,000 개의 이미지를 사용하여 네트워크가 이미지를 분류하는 방법을 얼마나 정확하게 학습했는지 평가
#
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
# </table>
#
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Activation

# %% [markdown]
# ### Data Load

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()

print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 
               'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.imshow(train_images[0], cmap="gray")
plt.colorbar()

# %% [markdown]
# ### Feature Scaling

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(1, 26):
    plt.subplot(5,5,i)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
    plt.gca().set_xticks([])
    plt.gca().set_yticks([])

# %% [markdown]
# ### 2차원 Data를 1차원으로 Flatten

# %%
X_train = train_images.reshape(-1, 784).astype("float32")
X_test = test_images.reshape(-1, 784).astype("float32")

train_images.shape, test_images.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# ### One-Hot Encoding

# %%
y_train = tf.keras.utils.to_categorical(train_labels)
y_test  = tf.keras.utils.to_categorical(test_labels)

y_train.shape, y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %% [markdown]
# ### Model Build

# %%
model = tf.keras.Sequential()
model.add(Dense(256, input_shape=(784,)))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(10))
model.add(Activation('softmax'))

# %%
model.compile(loss="categorical_crossentropy", 
              optimizer="adam", metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size=128, 
                    epochs=40, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/40
# 375/375 [==============================] - 3s 5ms/step - loss: 0.5848 - accuracy: 0.7898 - val_loss: 0.4360 - val_accuracy: 0.8404
# Epoch 2/40
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4095 - accuracy: 0.8506 - val_loss: 0.3770 - val_accuracy: 0.8663
# Epoch 3/40
# 375/375 [==============================] - 3s 7ms/step - loss: 0.3709 - accuracy: 0.8651 - val_loss: 0.3651 - val_accuracy: 0.8621
# Epoch 4/40
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3512 - accuracy: 0.8706 - val_loss: 0.3363 - val_accuracy: 0.8799
# Epoch 5/40
# 375/375 [==============================] - 2s 7ms/step - loss: 0.3324 - accuracy: 0.8779 - val_loss: 0.3329 - val_accuracy: 0.8800
# Epoch 6/40
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3192 - accuracy: 0.8814 - val_loss: 0.3302 - val_accuracy: 0.8798
# Epoch 7/40
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3092 - accuracy: 0.8857 - val_loss: 0.3112 - val_accuracy: 0.8872
# Epoch 8/40
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3005 - accuracy: 0.8871 - val_loss: 0.3248 - val_accuracy: 0.8809
# Epoch 9/40
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2902 - accuracy: 0.8918 - val_loss: 0.3078 - val_accuracy: 0.8878
# Epoch 10/40
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2828 - accuracy: 0.8934 - val_loss: 0.3141 - val_accuracy: 0.8852
# Epoch 11/40
# 375/375 [==============================] - 2s 7ms/step - loss: 0.2749 - accuracy: 0.8970 - val_loss: 0.3121 - val_accuracy: 0.8876
# Epoch 12/40
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2663 - accuracy: 0.8994 - val_loss: 0.3151 - val_accuracy: 0.8867
# Epoch 13/40
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2628 - accuracy: 0.9007 - val_loss: 0.3072 - val_accuracy: 0.8887
# Epoch 14/40
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2596 - accuracy: 0.9038 - val_loss: 0.3038 - val_accuracy: 0.8909
# Epoch 15/40
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2472 - accuracy: 0.9060 - val_loss: 0.3107 - val_accuracy: 0.8899
# Epoch 16/40
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2474 - accuracy: 0.9057 - val_loss: 0.3104 - val_accuracy: 0.8919
# Epoch 17/40
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2440 - accuracy: 0.9075 - val_loss: 0.2961 - val_accuracy: 0.8935
# Epoch 18/40
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2378 - accuracy: 0.9084 - val_loss: 0.3355 - val_accuracy: 0.8859
# Epoch 19/40
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2323 - accuracy: 0.9112 - val_loss: 0.3065 - val_accuracy: 0.8939
# Epoch 20/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2289 - accuracy: 0.9124 - val_loss: 0.2962 - val_accuracy: 0.8956
# Epoch 21/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2245 - accuracy: 0.9146 - val_loss: 0.3340 - val_accuracy: 0.8896
# Epoch 22/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2201 - accuracy: 0.9173 - val_loss: 0.3038 - val_accuracy: 0.8939
# Epoch 23/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2178 - accuracy: 0.9168 - val_loss: 0.2956 - val_accuracy: 0.8946
# Epoch 24/40
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2101 - accuracy: 0.9200 - val_loss: 0.3162 - val_accuracy: 0.8938
# Epoch 25/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2151 - accuracy: 0.9187 - val_loss: 0.3246 - val_accuracy: 0.8907
# Epoch 26/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2087 - accuracy: 0.9206 - val_loss: 0.3113 - val_accuracy: 0.8969
# Epoch 27/40
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2053 - accuracy: 0.9219 - val_loss: 0.3197 - val_accuracy: 0.8923
# Epoch 28/40
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2004 - accuracy: 0.9231 - val_loss: 0.3172 - val_accuracy: 0.8967
# Epoch 29/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2001 - accuracy: 0.9237 - val_loss: 0.3201 - val_accuracy: 0.8968
# Epoch 30/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1999 - accuracy: 0.9239 - val_loss: 0.3394 - val_accuracy: 0.8896
# Epoch 31/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1935 - accuracy: 0.9251 - val_loss: 0.3050 - val_accuracy: 0.8982
# Epoch 32/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1893 - accuracy: 0.9279 - val_loss: 0.3133 - val_accuracy: 0.8949
# Epoch 33/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1926 - accuracy: 0.9267 - val_loss: 0.3127 - val_accuracy: 0.8992
# Epoch 34/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1838 - accuracy: 0.9304 - val_loss: 0.3144 - val_accuracy: 0.8989
# Epoch 35/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1823 - accuracy: 0.9303 - val_loss: 0.3439 - val_accuracy: 0.8867
# Epoch 36/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1829 - accuracy: 0.9297 - val_loss: 0.3237 - val_accuracy: 0.8997
# Epoch 37/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1797 - accuracy: 0.9312 - val_loss: 0.3167 - val_accuracy: 0.9000
# Epoch 38/40
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1758 - accuracy: 0.9325 - val_loss: 0.3274 - val_accuracy: 0.8962
# Epoch 39/40
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1749 - accuracy: 0.9335 - val_loss: 0.3268 - val_accuracy: 0.8932
# Epoch 40/40
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1724 - accuracy: 0.9342 - val_loss: 0.3400 - val_accuracy: 0.8953

# %% [markdown]
# ### model 평가

# %%
score = model.evaluate(X_test, y_test, verbose=0)

# %%
print(model.metrics_names)
print("Test loss :", score[0])          # evaluation of loss function
print("Test accuracy :", score[1])
# Out:
# ['loss', 'accuracy']
# Test loss : 0.3689979016780853
# Test accuracy : 0.88919997215271

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'])

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test']);

# %%
y_predict = model.predict(X_test).argmax(axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 313/313 [==============================] - 1s 1ms/step

# %%
correct_indices = np.nonzero(y_predict == y_true)[0]
incorrect_indices = np.nonzero(y_predict != y_true)[0]
print(correct_indices.shape)
print(incorrect_indices.shape)
# Out:
# (8892,)
# (1108,)

# %%
plt.figure(figsize=(8, 8))
for i, correct in enumerate(np.random.choice(correct_indices, 9), 1):
    plt.subplot(3, 3, i)
    plt.imshow(X_test[correct].reshape(28, 28), cmap='gray')
    plt.title("predicted {}, classified {}".format(y_predict[correct], 
                                                   y_true[correct]))
    plt.tight_layout()
    
plt.figure(figsize=(8, 8))
for i, incorrect in enumerate(np.random.choice(incorrect_indices, 9), 1):
    plt.subplot(3, 3, i)
    plt.imshow(X_test[incorrect].reshape(28, 28), cmap='gray')
    plt.title("predicted {}, classified {}".format(y_predict[incorrect], 
                                                   y_true[incorrect]))
    plt.tight_layout()
