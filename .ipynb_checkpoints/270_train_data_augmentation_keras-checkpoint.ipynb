# %% [markdown]
# # Keras에서 데이터 증강을 사용한 Training
# Cifar10 image 분류기를 처음부터 훈련하고 데이터 증강이 얼마나 많은 이점을 가져올 수 있는지 확인할 것입니다.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import time

# %% [markdown]
# 그리고 데이터 세트의 처음 몇 개 이미지를 표시하는 도우미 함수를 정의할 것입니다.

# %%
def visualize_data(images, categories, class_names):
    fig = plt.figure(figsize=(14, 6))
    for i in range(21):
        plt.subplot(3, 7, i+1)
        plt.imshow(images[i])
        class_index = categories[i].argmax()
        plt.title(class_names[class_index])
        plt.xticks([])
        plt.yticks([])
    plt.show()

# %% [markdown]
# ## Cifar10 데이터 세트 로드
# Cifar10 데이터 세트를 가져오고 해당 클래스와 함께 몇 가지 이미지를 플로팅해 봅니다.

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)

X_train = X_train / 255.0
y_train = to_categorical(y_train, 10)

X_test = X_test / 255.0
y_test = to_categorical(y_test, 10)

visualize_data(X_train, y_train, class_names)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %% [markdown]
# ## Model Train

# %% [markdown]
# ## 모델 정의
# VGG 스타일의 합성곱 신경망 분류기를 생성하는 함수를 만듭니다.
#
# - VGG 스타일
#     - 3 x 3 필터로 두 차례 컨볼루션을 하는 것과 5 x 5 필터로 한 번 컨볼루션을 하는 것이 결과적으로 동일한 사이즈의 특성맵을 산출
#     - 3x3 필터가 두개면 18개의 가중치이고 5x5 필터 한개는 25개의 가중치인데, CNN에서 가중치는 모두 훈련이 필요한 것들이므로, 가중치가 적다는 것은 그만큼 훈련시켜야할 것의 갯수가 작아진다. 따라서 학습의 속도가 빨라진다.

# %%
def create_model():
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPool2D((2,2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same',))
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same',))
    model.add(layers.MaxPool2D((2,2)))

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same',))
    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same',))
    model.add(layers.MaxPool2D((2,2)))

    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %% [markdown]
# ## 데이터 증강 없이 훈련
#
# 데이터 증강 후의 모델과 비교하기 위해 데이터 증강 없이 Train

# %%
model_no_aug = create_model()
model_no_aug.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
s = time.time()

batch_size = 32
epochs = 16

history_no_aug = model_no_aug.fit(
            X_train, y_train,
            epochs=epochs, batch_size=batch_size,
            validation_data=(X_test, y_test))

loss_no_aug, acc_no_aug = model_no_aug.evaluate(X_test,  y_test)
# Out:
# Epoch 1/16
# 1563/1563 [==============================] - 21s 7ms/step - loss: 1.4961 - accuracy: 0.4524 - val_loss: 1.1468 - val_accuracy: 0.5910
# Epoch 2/16
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.9743 - accuracy: 0.6557 - val_loss: 0.8897 - val_accuracy: 0.6873
# Epoch 3/16
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.7847 - accuracy: 0.7245 - val_loss: 0.7960 - val_accuracy: 0.7232
# Epoch 4/16
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6602 - accuracy: 0.7679 - val_loss: 0.7500 - val_accuracy: 0.7437
# Epoch 5/16
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5598 - accuracy: 0.8039 - val_loss: 0.7264 - val_accuracy: 0.7555
# Epoch 6/16
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4811 - accuracy: 0.8297 - val_loss: 0.7500 - val_accuracy: 0.7633
# Epoch 7/16
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4086 - accuracy: 0.8555 - val_loss: 0.7550 - val_accuracy: 0.7572
# Epoch 8/16
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3447 - accuracy: 0.8776 - val_loss: 0.8292 - val_accuracy: 0.7600
# Epoch 9/16
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2954 - accuracy: 0.8945 - val_loss: 0.8836 - val_accuracy: 0.7501
# Epoch 10/16
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2624 - accuracy: 0.9066 - val_loss: 0.9174 - val_accuracy: 0.7555
# Epoch 11/16
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.2295 - accuracy: 0.9179 - val_loss: 0.9644 - val_accuracy: 0.7414
# Epoch 12/16
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2076 - accuracy: 0.9259 - val_loss: 1.0589 - val_accuracy: 0.7549
# Epoch 13/16
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1917 - accuracy: 0.9329 - val_loss: 1.0199 - val_accuracy: 0.7555
# Epoch 14/16
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1832 - accuracy: 0.9353 - val_loss: 1.1910 - val_accuracy: 0.7576
# Epoch 15/16
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1732 - accuracy: 0.9397 - val_loss: 1.1799 - val_accuracy: 0.7530
# Epoch 16/16
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1580 - accuracy: 0.9450 - val_loss: 1.2276 - val_accuracy: 0.7531
# 313/313 [==============================] - 1s 4ms/step - loss: 1.2276 - accuracy: 0.7531

# %%
print(f"경과 시간(분) :", (time.time() - s) / 60)
# Out:
# 경과 시간(분) : 2.9351830800374348

# %% [markdown]
# ## Data Augmentation 정의
# 이제 데이터 증강 파이프라인을 설정하고 몇 가지 증강 이미지를 표시합니다.

# %%
datagen = ImageDataGenerator(
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    )
datagen.fit(X_train)

it = datagen.flow(X_train, y_train, shuffle=False)
batch_images, batch_labels = next(it)
visualize_data(batch_images, batch_labels, class_names)

# %% [markdown]
# ## Data Augmentation을 이용한 Train

# %%
s = time.time()
model_aug = create_model()

history_aug = model_aug.fit(
            datagen.flow(X_train, y_train, batch_size=batch_size),
            epochs=epochs,
            validation_data=(X_test, y_test))
loss_aug, acc_aug = model_aug.evaluate(X_test,  y_test)
# Out:
# Epoch 1/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.6348 - accuracy: 0.3977 - val_loss: 1.2990 - val_accuracy: 0.5400
# Epoch 2/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.1551 - accuracy: 0.5874 - val_loss: 0.9449 - val_accuracy: 0.6635
# Epoch 3/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.9636 - accuracy: 0.6603 - val_loss: 0.9212 - val_accuracy: 0.6835
# Epoch 4/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.8665 - accuracy: 0.6949 - val_loss: 0.8258 - val_accuracy: 0.7148
# Epoch 5/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.7937 - accuracy: 0.7212 - val_loss: 0.7963 - val_accuracy: 0.7308
# Epoch 6/16
# 1563/1563 [==============================] - 32s 21ms/step - loss: 0.7478 - accuracy: 0.7389 - val_loss: 0.7751 - val_accuracy: 0.7416
# Epoch 7/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.7108 - accuracy: 0.7492 - val_loss: 0.7644 - val_accuracy: 0.7499
# Epoch 8/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.6829 - accuracy: 0.7625 - val_loss: 0.6669 - val_accuracy: 0.7789
# Epoch 9/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.6611 - accuracy: 0.7691 - val_loss: 0.7082 - val_accuracy: 0.7567
# Epoch 10/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.6386 - accuracy: 0.7789 - val_loss: 0.6934 - val_accuracy: 0.7696
# Epoch 11/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.6155 - accuracy: 0.7853 - val_loss: 0.6536 - val_accuracy: 0.7855
# Epoch 12/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.6011 - accuracy: 0.7908 - val_loss: 0.6537 - val_accuracy: 0.7832
# Epoch 13/16
# 1563/1563 [==============================] - 32s 20ms/step - loss: 0.5905 - accuracy: 0.7946 - val_loss: 0.6455 - val_accuracy: 0.7862
# Epoch 14/16
# 1563/1563 [==============================] - 32s 20ms/step - loss: 0.5716 - accuracy: 0.8021 - val_loss: 0.6543 - val_accuracy: 0.7872
# Epoch 15/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.5619 - accuracy: 0.8048 - val_loss: 0.6011 - val_accuracy: 0.7998
# Epoch 16/16
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.5544 - accuracy: 0.8072 - val_loss: 0.6373 - val_accuracy: 0.7928
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6373 - accuracy: 0.7928

# %%
print(f"경과 시간(분) :", (time.time() - s) / 60)
# Out:
# 경과 시간(분) : 8.400383539994557

# %% [markdown]
# # Results
# 단일 plot에서 두 개 model을 비교

# %%
fig = plt.figure()

plt.plot(history_aug.history['loss'],
         label='data augmented : train_loss',
         c='red', ls='-')
plt.plot(history_aug.history['val_loss'],
         label='data augmented : val_loss',
         c='red',ls='--')

plt.plot(history_no_aug.history['loss'],
         label='no augmented : train_loss',
         c='blue', ls='-')
plt.plot(history_no_aug.history['val_loss'],
         label='no augmented : val_loss',
         c='blue', ls='--')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# augement된 data에 비해 no augmented data는 overfitting 이 심한 것을 알 수 있다.
